# %% [markdown]
# <h1 align='center'> CS353 Machine Learning Lab</h1>
# <h1 align='center'>Lab-2 (05/02/21)</h1>
# <h2 align='center'>Shumbul Arifa (181CO152)</h2>

# %% [markdown]
# ## Task:
# Perform naive bayes classification on breast cancer standard dataset.
#
# **Attributes:**
#
# 1. radius (mean of distances from center to points on the perimeter)
#
# 2. texture (standard deviation of gray-scale values)
#
# 3. perimeter
#
# 4. area
#
# 5. smoothness (local variation in radius lengths)
#
# 6. compactness (perimeter^2 / area - 1.0)
#
# 7. concavity (severity of concave portions of the contour)
#
# 8. concave points (number of concave portions of the contour)
#
# 9. symmetry
#
# 10. fractal dimension (“coastline approximation” - 1)
#
# The mean, standard error, and “worst” or largest (mean of the three worst/largest values) of these features were computed for each image, resulting in 30 features. For instance, field 0 is Mean Radius, field 10 is Radius SE, field 20 is Worst Radius.
#
# **class:**
# - WDBC-Malignant
#
# - WDBC-Benign
#
# **Results:**
#
# Accuracy Obtained = 94.73 %

# %% [markdown]
# ## Breast Cancer dataset
#
# The breast cancer dataset is a classic and very easy binary classification dataset. \
# The dataset is described below:
#
#
# >Features | Quantity
# >--- | ---
# >Classes | 2
# >Samples per Class | 212(M),357(B)
# >Samples Total | 569
# >Dimensionality | 30
# >Features | real, positive

# %% [markdown]
# # Importing Libraries

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from scipy.stats import norm
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report, recall_score, precision_score, f1_score, plot_confusion_matrix
from sklearn.datasets import load_breast_cancer
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading dataset

# %%
data = load_breast_cancer()
X, y, col_names = data['data'], data['target'], data['feature_names']
X = pd.DataFrame(X, columns=col_names)

# %%
X.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %% [markdown]
# # Splitting Data

# %% [markdown]
# We are using X-y split method with test size 20 % and random state 5.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
X_train.head()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 306        13.20         15.82           84.07      537.3          0.08511
# 410        11.36         17.57           72.49      399.8          0.08858
# 197        18.08         21.84          117.40     1024.0          0.07371
# 376        10.57         20.22           70.15      338.3          0.09073
# 244        19.40         23.50          129.10     1155.0          0.10270
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 306           0.05251        0.001461             0.003261         0.1632
# 410           0.05313        0.027830             0.021000         0.1601
# 197           0.08642        0.110300             0.057780         0.1770
# 376           0.16600        0.228000             0.059410         0.2188
# 244           0.15580        0.204900             0.088860         0.1978
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# ...

# %%
X_test.head()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 28         15.30         25.27          102.40      732.4          0.10820
# 163        12.34         22.22           79.85      464.5          0.10120
# 123        14.50         10.89           94.28      640.7          0.11010
# 361        13.30         21.57           85.24      546.1          0.08582
# 549        10.82         24.21           68.89      361.6          0.08192
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 28            0.16970         0.16830              0.08751         0.1926
# 163           0.10150         0.05370              0.02822         0.1551
# 123           0.10990         0.08842              0.05778         0.1856
# 361           0.06373         0.03344              0.02424         0.1815
# 549           0.06602         0.01548              0.00816         0.1976
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# ...

# %% [markdown]
# # Implementing Naive Bayes Classifier
#
#
# Naive Bayes is a simple probabilistic model. We assume that the dataset is representative of samples in the real world, and assume they have similar distributions. We then look at each value given for the validation dataset, and see how many rows in the training data have similar values. We take this probability as the probability that the validation data belongs to a particular sample.
#
# 1. Using python from scratch
# 2. Using sklearn standard library

# %% [markdown]
# ## Part - 1: Using python from scratch

# %%
means = X_train.groupby(y_train).apply(np.mean) 
stds = X_train.groupby(y_train).apply(np.std)
probs = X_train.groupby(y_train).apply(lambda x: len(x))/X_train.shape[0]

# %%
means
# Out:
#    mean radius  mean texture  mean perimeter   mean area  mean smoothness  \
# 0    17.418841     21.443110      114.933720  971.482927         0.102330
# 1    12.172498     17.749175       78.246357  465.044330         0.092968
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0          0.141595        0.156754             0.086570       0.191178
# 1          0.079921        0.044955             0.025684       0.174594
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                0.062316  ...     20.982561      29.036768       140.004146
# 1                0.062752  ...     13.409753      23.285361        87.234399
#
#     worst area  worst smoothness  worst compactness  worst concavity  \
# 0  1396.190854          0.143779           0.363348          0.44101
# 1   561.907560          0.125461           0.181362          0.16283
#
#    worst concave points  worst symmetry  worst fractal dimension
# ...

# %%
stds
# Out:
#    mean radius  mean texture  mean perimeter   mean area  mean smoothness  \
# 0     3.112415      3.833583       21.172813  352.429935         0.012418
# 1     1.803035      3.871083       11.979191  136.467688         0.013783
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0          0.051954        0.071969             0.032975       0.027754
# 1          0.033661        0.041980             0.016055       0.024931
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                0.007162  ...      4.038980       5.562354        27.366505
# 1                0.006690  ...      2.010013       5.326095        13.788307
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0  541.233268          0.020665           0.161386         0.171260
# 1  166.605245          0.020312           0.092800         0.132248
#
#    worst concave points  worst symmetry  worst fractal dimension
# ...

# %%
probs
# Out:
# 0    0.36044
# 1    0.63956
# dtype: float64

# %% [markdown]
# ### Function to perform naive baiyes classification

# %%
y_pred=[]

for sample in range(X_val.shape[0]): #for each sample in the validation data,
  p = {} #start by making an empty dictionary to hold probabilities of belonging to each class

  for each_class in np.unique(y_train):
    p[each_class] = probs.iloc[each_class] #the standard probability that it would belong to each class.

    for index, param in enumerate(X_val.iloc[sample]): #enum returns the index and value, so we're basically going through each column (param) of our sample, and index is column number
      p[each_class] *= norm.pdf(param, means.iloc[each_class, index], stds.iloc[each_class, index]) #using a probability distribution function is better if we have continuous data,
      #if we were to bin and solve, we'd get similar results, but it wouldn't be this high accuracy.

  y_pred.append(pd.Series(p).values.argmax())

# %% [markdown]
# ### Computing Accuracy

# %%
print("Accuracy of our model using python from scrath is: ")
print(accuracy_score(y_test, y_pred))
# Out:
# Accuracy of our model using python from scrath is:
# 0.9385964912280702

# %% [markdown]
# ### Confusion Matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[44,  4],
#        [ 3, 63]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93        48
#            1       0.94      0.95      0.95        66
#
#     accuracy                           0.94       114
#    macro avg       0.94      0.94      0.94       114
# weighted avg       0.94      0.94      0.94       114

# %% [markdown]
# ## Part - 2: Using classifier from sklearn

# %%
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %% [markdown]
# ### Computing Accuracy

# %%
print("Accuracy of our model using sklearn std library is: ")
sk_pred = model.predict(X_test)
print(accuracy_score(y_test, sk_pred))
# Out:
# Accuracy of our model using sklearn std library is:
# 0.9473684210526315

# %% [markdown]
# ### Confusion Matrix

# %%
print(classification_report(y_test,sk_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94        48
#            1       0.94      0.97      0.96        66
#
#     accuracy                           0.95       114
#    macro avg       0.95      0.94      0.95       114
# weighted avg       0.95      0.95      0.95       114

# %%
plot_confusion_matrix(model, X_test, y_test, display_labels=data.target_names,cmap=plt.cm.Blues)  
plt.show()

# %% [markdown]
# <h1 align='center'> Observation </h1>
